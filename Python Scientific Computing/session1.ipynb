# %%
# %pip install numpy
# %pip install mathplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 330.3 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.8 kB 262.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.8 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 294.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB 259.2 kB/s eta 0:00:49
#    ---------------------------------------- 0.0/12.6 MB 259.2 kB/s eta 0:00:49
# ...

# %%
print("Hello World")
print("Marhaba")
# Out:
# Hello World
# Marhaba
