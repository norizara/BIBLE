# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [
    [
        [5, 1, 2],
        [2, 6, 1],
        [1, 1, 7]
    ],
    [
        [10, 2, -1],
        [1, 8, 2],
        [2, -1, 9]
    ],
    [
        [6, -1, 1],
        [3, 7, 2],
        [2, -2, 8]
    ],
    [
        [4, 2, 1],
        [1, 5, 2],
        [3, 1, 6]
    ],
    [
        [8, -1, 2],
        [1, 9, 1],
        [2, 3, 10]
    ]
]
y = [
    [12, 14, 17],
    [13, 18, 16],
    [11, 19, 14],
    [10, 13, 15],
    [17, 14, 19]
]


def diagonal_dominant(x):
    x = np.array(x)
    diag = np.diag(np.abs(x))
    off_diag = np.sum(np.abs(x), axis = 1) - diag
    result = np.all(diag > off_diag)
    return result

def gauss_seidel(x, y, tol=0.001, max_iter=45):
    if not diagonal_dominant(x):
        return
    else:
        print("Diagonal Dominant")

    x = np.array(x)
    y = np.array(y)

    diag = np.diag(x)
    x = -x
    np.fill_diagonal(x, 0)

    old_res = np.zeros(len(x[0]))

    for i in range(max_iter):
        new_res = np.array(old_res)

        for idx, row in enumerate(x):
            new_res[idx] = (y[idx] + np.dot(row, new_res)) / diag[idx]

        print(f"Iteration {i+1} : {new_res}")

        diff = np.sqrt(np.dot(old_res-new_res, old_res-new_res))

        if diff < tol:
            print("Converged")
            print(f"Result: {new_res}")
            return new_res
        
        old_res = new_res


for i in range(len(x)):
    print(f"Matrix #{i+1}:")
    gauss_seidel(x[i], y[i])
    print("")
# Out:
# Matrix #1:
# Diagonal Dominant
# Iteration 1 : [2.4        1.53333333 1.86666667]
# Iteration 2 : [1.34666667 1.57333333 2.01142857]
# Iteration 3 : [1.2807619  1.5711746  2.02115193]
# Iteration 4 : [1.27730431 1.57070658 2.02171273]
# Iteration 5 : [1.27717359 1.57065668 2.02173853]
# Converged
# Result: [1.27717359 1.57065668 2.02173853]
#
# Matrix #2:
# Diagonal Dominant
# Iteration 1 : [1.3        2.0875     1.72083333]
# Iteration 2 : [1.05458333 1.68796875 1.73097801]
# Iteration 3 : [1.13550405 1.67531749 1.71158993]
# Iteration 4 : [1.13609549 1.68009058 1.71198884]
# Iteration 5 : [1.13518077 1.68010519 1.71219374]
# Converged
# Result: [1.13518077 1.68010519 1.71219374]
#
# Matrix #3:
# Diagonal Dominant
# Iteration 1 : [1.83333333 1.92857143 1.77380952]
# Iteration 2 : [1.85912698 1.41071429 1.63789683]
# Iteration 3 : [1.79546958 1.47682823 1.67033966]
# Iteration 4 : [1.80108143 1.46515377 1.66601809]
# Iteration 5 : [1.79985595 1.46691371 1.66676444]
# Iteration 6 : [1.80002488 1.46662807 1.6666508 ]
# Converged
# Result: [1.80002488 1.46662807 1.6666508 ]
#
# Matrix #4:
# Diagonal Dominant
# Iteration 1 : [2.5 2.1 0.9]
# Iteration 2 : [1.225 1.995 1.555]
# Iteration 3 : [1.11375    1.75525    1.65058333]
# Iteration 4 : [1.20972917 1.69782083 1.61216528]
# Iteration 5 : [1.24804826 1.70552424 1.59172183]
# Iteration 6 : [1.24930742 1.71344978 1.58977132]
# Iteration 7 : [1.24583228 1.71492502 1.59126303]
# Iteration 8 : [1.24472174 1.71455044 1.59188072]
# Iteration 9 : [1.2447546  1.71429679 1.59190657]
# Converged
# Result: [1.2447546  1.71429679 1.59190657]
#
# Matrix #5:
# Diagonal Dominant
# Iteration 1 : [2.125      1.31944444 1.07916667]
# Iteration 2 : [2.02013889 1.21118827 1.13261574]
# Iteration 3 : [1.9932446  1.20823774 1.13887976]
# Iteration 4 : [1.99130978 1.20775672 1.13941103]
# Iteration 5 : [1.99111683 1.20771913 1.1394609 ]
# Converged
# Result: [1.99111683 1.20771913 1.1394609 ]

# %%
x = [
    [
        [9, -1, 2],
        [1, 8, -1],
        [3, -2, 10]
    ],
    [
        [7, 2, 1],
        [1, 6, 2],
        [2, 3, 9]
    ],
    [
        [6, 1, 2],
        [2, 7, 1],
        [3, 2, 8]
    ],
    [
        [8, 1, -2],
        [2, 9, 1],
        [1, -1, 7]
    ],
    [
        [10, 3, 1],
        [2, 7, 2],
        [3, 1, 6]
    ]
]
y = [
    [17, 15, 19],
    [12, 13, 14],
    [13, 15, 16],
    [16, 14, 13],
    [18, 16, 17]
]


def diagonal_dominant(x):
    x = np.array(x)
    diag = np.diag(np.abs(x))
    off_diag = np.sum(np.abs(x), axis = 1) - diag
    result = np.all(diag > off_diag)
    return result

def gauss_seidel(x, y, tol = 0.001, max_iter=45):
    if not diagonal_dominant(x):
        print("Not Dominant")
        return
    else:
        print("Dominant")

    x = np.array(x)
    y = np.array(y)

    diag = np.diag(x)
    x = -x
    np.fill_diagonal(x,0)

    old_res = np.zeros(len(x[0]))

    for i in range(max_iter):
        new_res = np.array(old_res)

        print(f"Iteration {i+1} : {new_res}")

        for idx, row in enumerate(x):
            new_res[idx] = (y[idx] + np.dot(row, new_res)) / diag[idx]

        diff = np.sqrt(np.dot(old_res-new_res, old_res-new_res))
        if diff < tol:
            print("Convergence")
            print(f"Result: {new_res}")
            return new_res
        
        old_res = new_res

for i in range(len(x)):
    print(f"Matrix #{i+1}: ")
    gauss_seidel(x[i], y[i])
    print("")
# Out:
# Matrix #1:
# Dominant
# Iteration 1 : [0. 0. 0.]
# Iteration 2 : [1.88888889 1.63888889 1.66111111]
# Iteration 3 : [1.70185185 1.86990741 1.76342593]
# Iteration 4 : [1.70478395 1.88233025 1.76503086]
# Iteration 5 : [1.70580761 1.88240291 1.7647383 ]
# Convergence
# Result: [1.7058807  1.8823572  1.76470723]
#
# Matrix #2:
# Dominant
# Iteration 1 : [0. 0. 0.]
# Iteration 2 : [1.71428571 1.88095238 0.54761905]
# Iteration 3 : [1.09863946 1.80102041 0.71107332]
# Iteration 4 : [1.09812655 1.74662114 0.72932039]
# Iteration 5 : [1.11106248 1.73838279 0.72919185]
# Iteration 6 : [1.11343465 1.73803027 0.72878221]
# Convergence
# Result: [1.11359389 1.73814028 0.72871015]
#
# Matrix #3:
# Dominant
# Iteration 1 : [0. 0. 0.]
# Iteration 2 : [2.16666667 1.52380952 0.80654762]
# Iteration 3 : [1.64384921 1.55796485 0.99406533]
# Iteration 4 : [1.57565075 1.55066188 1.0214655 ]
# Iteration 5 : [1.56773452 1.54900935 1.02484722]
# Convergence
# Result: [1.5668827  1.54876963 1.02522658]
#
# Matrix #4:
# Dominant
# Iteration 1 : [0. 0. 0.]
# Iteration 2 : [2.         1.11111111 1.73015873]
# Iteration 3 : [2.29365079 0.85361552 1.65142353]
# Iteration 4 : [2.30615394 0.8595854  1.65049021]
# Iteration 5 : [2.30517438 0.85990678 1.65067606]
# Convergence
# Result: [2.30518067 0.85988473 1.65067201]
#
# Matrix #5:
# Dominant
# Iteration 1 : [0. 0. 0.]
# Iteration 2 : [1.8        1.77142857 1.63809524]
# Iteration 3 : [1.1047619  1.50204082 2.03061224]
# Iteration 4 : [1.14632653 1.37801749 2.03050049]
# Iteration 5 : [1.1835447  1.36741566 2.01365837]
# Iteration 6 : [1.18840946 1.37083776 2.01065564]
# Iteration 7 : [1.18768311 1.37190321 2.01084124]
# Convergence
# Result: [1.18734491 1.37194681 2.01100308]

# %%
x = [1, 2, 3, 4, 5]
y = [3, 5, 7, 9, 11]

x = np.array(x)
y = np.array(y)

A = np.vstack([x, np.ones(len(x))]).T
Y = y[:, np.newaxis]

alpha = np.linalg.inv(np.dot(A.T, A))
alpha = np.dot(alpha, A.T)
alpha = np.dot(alpha, Y)

plt.plot(x, y, "ro")
plt.plot(x, alpha[0]*x+alpha[1], "b-")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [2.1, 2.3, 2.6, 3.0, 3.5, 4.1]
y = [5.2, 5.5, 6.0, 6.8, 7.1, 8.0]

x = np.array(x)
y = np.array(y)

A = np.vstack([x, np.ones(len(x))]).T
Y = y[:, np.newaxis]

alpha = np.linalg.inv(np.dot(A.T,A))
alpha = np.dot(alpha, A.T)
alpha = np.dot(alpha, Y)

print(f"Alpha: {alpha}")

plt.plot(x, y, "ro")
plt.plot(x, alpha[0] * x + alpha[1], "b-")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["Data Dots", "Plot Line"], loc="lower right")
plt.show
# Out:
# Alpha: [[1.38018433]
#  [2.38479263]]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def f(x):
    return x**3 - x - 2

def g(x):
    return 3*(x**2) - 1

def newton_raphson(x, tol=0.01, max_iter=20):
    found = False
    for i in range(max_iter):
        x = x - (f(x)/g(x))

        if np.abs(f(x)) < tol:
            print(f"Root found at {i+1} iteration: {x}")
            return
        
newton_raphson(1.5)
# Out:
# Root found at 1 iteration: 1.5217391304347827

# %%
def f(x):
    return x**2 + 2*x + 1

a = 1
b = 5
points = 1000
width = (b-a) / (points-1)
x = np.linspace(a, b, points)

rightRiemann = width * np.sum(f(x[1:]))
print(f"Right: {rightRiemann}")
mid = (x[:-1] + x[1:]) / 2
midRiemann = width*np.sum(f(mid))
print(f"Mid: {midRiemann}")
# Out:
# Right: 69.39740808542943
# Mid: 69.33332798931731
