# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [
    [
        [8, 4, 2],
        [1, 6, 3],
        [5, 6, 12]
    ],
    [
        [12, -7, -1],
        [1, -7, 2],
        [8, -1, 12]
    ],
    [
        [4, 2, 7],
        [3, -7, 5],
        [2, -1, 3]
    ],
    [   
        [14, 2, 1],
        [1, 8, 4],
        [9, 8, 18]
    ],
    [   
        [1, 3, 6],
        [9, 1, 12],
        [15, 18, 1]
    ]
]
y = [
    [10, 12, 15],
    [21, 12, 4],
    [8, 4, 5],
    [7, 2, 6],
    [4, 7, 6]
]


def diagonal_dominant(x):
    x = np.array(x)
    diag = np.diag(np.abs(x))
    off_diag = np.sum(np.abs(x), axis = 1) - diag
    result = np.all(diag > off_diag)
    return result

def gauss_seidel(x, y, tol=0.002, max_iter=20):
    if not diagonal_dominant:
        print("Not Diagonally Dominant!")
        return
    else:
        print("Diagonal Dominant")

    x = np.array(x)
    y = np.array(y)

    diag = np.diag(x)
    x = -x
    np.fill_diagonal(x,0)

    old_res = np.zeros(len(x[0]))

    for i in range(max_iter):
        new_res = np.array(old_res)

        for idx, row in enumerate(x):
            new_res[idx] = (y[idx] + np.dot(row, new_res)) / diag[idx]
        
        print(f"Iteration #{i+1} : {new_res}")
        diff = np.sqrt(np.dot(old_res-new_res, old_res-new_res))
        print(f"Difference: {diff}")

        if diff < tol:
            print("Convergent")
            return new_res
        else:
            print("Not Convergent")

        old_res = new_res

for i in range(len(x)):
    print(f"Matrix #{i+1}")
    gauss_seidel(x[i], y[i])
    print("")
# Out:
# Matrix #1
# Diagonal Dominant
# Iteration #1 : [ 1.25        1.79166667 -0.16666667]
# Difference: 2.190969470855818
# Not Convergent
# Iteration #2 : [0.39583333 2.01736111 0.07638889]
# Difference: 0.9163049054675799
# Not Convergent
# Iteration #3 : [0.22222222 1.92476852 0.19502315]
# Difference: 0.22975703161001523
# Not Convergent
# Iteration #4 : [0.23885995 1.86267843 0.2191358 ]
# Difference: 0.06865429955384911
# Not Convergent
# Iteration #5 : [0.26387683 1.84645263 0.21682501]
# Difference: 0.029907537811802946
# Not Convergent
# Iteration #6 : [0.27256744 1.84615959 0.21335044]
# Difference: 0.009364029799255288
# Not Convergent
# Iteration #7 : [0.27358259 1.84772768 0.21214341]
# Difference: 0.0022240440534418565
# Not Convergent
# Iteration #8 : [0.27310031 1.84841158 0.21200242]
# Difference: 0.0008486424491626981
# Convergent
#
# Matrix #2
# Diagonal Dominant
# Iteration #1 : [ 1.75       -1.46428571 -0.95535714]
# Difference: 2.473729961711542
# Not Convergent
# Iteration #2 : [ 0.81622024 -1.87064201 -0.36670033]
# Difference: 1.1762597197414264
# Not Convergent
# Iteration #3 : [ 0.6282338  -1.72930955 -0.22959833]
# Difference: 0.2722328425469943
# Not Convergent
# Iteration #4 : [ 0.7221029  -1.67672768 -0.28779591]
# Difference: 0.12232423662530427
# Not Convergent
# Iteration #5 : [ 0.74792586 -1.68966656 -0.30608945]
# Difference: 0.034189089310782864
# Not Convergent
# Iteration #6 : [ 0.73885372 -1.69618931 -0.30058492]
# Difference: 0.012455920767948117
# Not Convergent
# Iteration #7 : [ 0.73550749 -1.69509462 -0.29826288]
# Difference: 0.004217517028303943
# Not Convergent
# Iteration #8 : [ 0.73633956 -1.69431231 -0.2987524 ]
# Difference: 0.0012425722344323047
# Convergent
#
# Matrix #3
# Diagonal Dominant
# Iteration #1 : [2.         0.28571429 0.42857143]
# Difference: 2.065261756400137
# Not Convergent
# Iteration #2 : [1.10714286 0.20918367 0.99829932]
# Difference: 1.0619042716380744
# Not Convergent
# Iteration #3 : [0.14838435 0.20523567 1.63615565]
# Difference: 1.1515616163149913
# Not Convergent
# Iteration #4 : [-0.96589023  0.18330108  2.37169384]
# Difference: 1.3353296952249967
# Not Convergent
# Iteration #5 : [-2.24211477  0.16173213  3.21532056]
# Difference: 1.5300066468069706
# Not Convergent
# Iteration #6 : [-3.70767704  0.13622452  4.18385953]
# Difference: 1.7568697035291336
# Not Convergent
# Iteration #7 : [-5.38986645  0.10709976  5.29561089]
# Difference: 2.016581394238466
# Not Convergent
# Iteration #8 : [-7.32086893  0.07363538  6.57179108]
# Difference: 2.31484909673258
# Not Convergent
# Iteration #9 : [-9.53745208  0.03522845  8.03671087]
# Difference: 2.6571988871818357
# Not Convergent
# Iteration #10 : [-1.20818582e+01 -8.86005648e-03  9.71828548e+00]
# Difference: 3.0501868335939326
# Not Convergent
# Iteration #11 : [-15.00256956  -0.05946875  11.64855679]
# Difference: 3.501294495208958
# Not Convergent
# Iteration #12 : [-18.35524     -0.11756229  13.8643059 ]
# Difference: 4.019119068968885
# Not Convergent
# Iteration #13 : [-22.20375418  -0.18424758  16.4077536 ]
# Difference: 4.613527337532396
# Not Convergent
# Iteration #14 : [-26.621445    -0.26079529  19.32736491]
# Difference: 5.295845726719484
# Not Convergent
# Iteration #15 : [-31.69249094  -0.34866404  22.67877261]
# Difference: 6.07907570430342
# Not Convergent
# Iteration #16 : [-37.51352005  -0.44952816  26.52583732]
# Difference: 6.978141609218571
# Not Convergent
# Iteration #17 : [-44.19545122  -0.56530959  30.94186429]
# Difference: 8.01017501445637
# Not Convergent
# Iteration #18 : [-51.86560771  -0.69821453  36.0110003 ]
# Difference: 9.194841170552678
# Not Convergent
# Iteration #19 : [-60.67014326  -0.85077547  41.82983702]
# Difference: 10.554713723366543
# Not Convergent
# Iteration #20 : [-70.77682704  -1.02589944  48.50925155]
# Difference: 12.115704851869188
# Not Convergent
#
# Matrix #4
# Diagonal Dominant
# Iteration #1 : [0.5    0.1875 0.    ]
# Difference: 0.5340002340823456
# Not Convergent
# Iteration #2 : [0.47321429 0.19084821 0.01190476]
# Difference: 0.02950268436444472
# Not Convergent
# Iteration #3 : [0.47188563 0.18506192 0.01514078]
# Difference: 0.006761537289335747
# Not Convergent
# Iteration #4 : [0.4724811  0.18336947 0.01559524]
# Difference: 0.0018508052283201756
# Convergent
#
# Matrix #5
# Diagonal Dominant
# Iteration #1 : [  4. -29. 468.]
# Difference: 468.91470439729227
# Not Convergent
# Iteration #2 : [  -2717.   18844. -298431.]
# Difference: 299506.60455322184
# Not Convergent
# Iteration #3 : [ 1.7340580e+06 -1.2025343e+07  1.9044531e+08]
# Difference: 191131508.54468414
# Not Convergent
# Iteration #4 : [-1.10659583e+09  7.67401873e+09 -1.21533400e+11]
# Difference: 121971300393.59491
# Not Convergent
# Iteration #5 : [ 7.06178342e+11 -4.89720428e+12  7.75570020e+13]
# Difference: 77836449936893.02
# Not Convergent
# Iteration #6 : [-4.50650399e+14  3.12516957e+15 -4.94932962e+16]
# Difference: 4.967162700746209e+16
# Not Convergent
# Iteration #7 : [ 2.87584269e+17 -1.99433886e+18  3.15843355e+19]
# Difference: 3.1698137974802354e+19
# Not Convergent
# Iteration #8 : [-1.83522996e+20  1.27269494e+21 -2.01556640e+22]
# Difference: 2.0228287487314684e+22
# Not Convergent
# Iteration #9 : [ 1.17115899e+23 -8.12175125e+23  1.28624138e+25]
# Difference: 1.290875870988769e+25
# Not Convergent
# Iteration #10 : [-7.47379572e+25  5.18292649e+26 -8.20819833e+27]
# Difference: 8.237773540375084e+27
# Not Convergent
# Iteration #11 : [ 4.76943120e+28 -3.30750428e+29  5.23809303e+30]
# Difference: 5.256966562596338e+30
# Not Convergent
# Iteration #12 : [-3.04363069e+31  2.11069646e+32 -3.34270902e+33]
# Difference: 3.3547532357872584e+33
# Not Convergent
# Iteration #13 : [ 1.94230452e+34 -1.34694898e+35  2.13316249e+36]
# Difference: 2.1408485557242557e+36
# Not Convergent
# Iteration #14 : [-1.23948903e+37  8.59560625e+37 -1.36128577e+39]
# Difference: 1.3661906603604743e+39
# Not Convergent
# Iteration #15 : [ 7.90984644e+39 -5.48531887e+40  8.68709700e+41]
# Difference: 8.718397737502518e+41
# Not Convergent
# Iteration #16 : [-5.04769863e+42  3.50047713e+43 -5.54370404e+44]
# Difference: 5.563678724698162e+44
# Not Convergent
# Iteration #17 : [ 3.22120811e+45 -2.23384281e+46  3.53773585e+47]
# Difference: 3.550482770303874e+47
# Not Convergent
# Iteration #18 : [-2.05562622e+48  1.42553530e+49 -2.25761961e+50]
# Difference: 2.2657541037128385e+50
# Not Convergent
# Iteration #19 : [ 1.31180570e+51 -9.09710782e+51  1.44070855e+53]
# Difference: 1.4458996115765395e+53
# Not Convergent
# Iteration #20 : [-8.37133807e+53  5.80535400e+54 -9.19393650e+55]
# Difference: 9.227063445814042e+55
# Not Convergent

# %%
x = [1.00, 1.39, 1.78, 2.16, 2.55, 2.94, 3.33, 3.71, 4.10, 4.49, 4.88, 5.27, 5.65, 6.04, 6.43, 6.82, 7.20, 7.59, 7.98, 8.37, 8.76, 9.14, 9.53, 9.92, 10.31, 10.69, 11.08, 11.47, 11.86, 12.24, 12.63, 13.02, 13.41, 13.80, 14.18, 14.57, 14.96, 15.35, 15.73, 16.12, 16.51, 16.90, 17.29, 17.67, 18.06, 18.45, 18.84, 19.22, 19.61, 20.00]

y = [5.97, 5.95, 6.13, 6.41, 6.57, 6.30, 5.31, 6.90, 7.30, 7.22, 6.15, 7.77, 7.84, 8.24, 7.05, 8.61, 8.83, 8.87, 8.67, 9.63, 8.24, 8.76, 9.06, 8.80, 10.88, 10.83, 9.71, 10.63, 11.33, 10.61, 12.04, 10.51, 12.20, 11.40, 11.07, 11.50, 12.98, 12.56, 12.44, 12.57, 12.36, 13.32, 14.22, 14.01, 14.42, 13.48, 15.14, 13.92, 13.97, 14.44]

x = np.array(x)
y = np.array(y)

A = np.vstack([x, np.ones(len(x))]).T
Y = y[:, np.newaxis]

alpha = np.linalg.inv(np.dot(A.T,A))
alpha = np.dot(alpha, A.T)
alpha = np.dot(alpha, Y)

print(f"Alpha: {alpha}")
print(x)
print(y)

plt.plot(x, y, "go")
plt.plot(x, alpha[0] * x + alpha[1], "y-")
plt.title("Least Square Regression")
plt.legend(["Data Points", "Fitted Line"], loc="lower right")
plt.show
# Out:
# Alpha: [[0.48639923]
#  [4.95520808]]
# [ 1.    1.39  1.78  2.16  2.55  2.94  3.33  3.71  4.1   4.49  4.88  5.27
#   5.65  6.04  6.43  6.82  7.2   7.59  7.98  8.37  8.76  9.14  9.53  9.92
#  10.31 10.69 11.08 11.47 11.86 12.24 12.63 13.02 13.41 13.8  14.18 14.57
#  14.96 15.35 15.73 16.12 16.51 16.9  17.29 17.67 18.06 18.45 18.84 19.22
#  19.61 20.  ]
# [ 5.97  5.95  6.13  6.41  6.57  6.3   5.31  6.9   7.3   7.22  6.15  7.77
#   7.84  8.24  7.05  8.61  8.83  8.87  8.67  9.63  8.24  8.76  9.06  8.8
#  10.88 10.83  9.71 10.63 11.33 10.61 12.04 10.51 12.2  11.4  11.07 11.5
#  12.98 12.56 12.44 12.57 12.36 13.32 14.22 14.01 14.42 13.48 15.14 13.92
#  13.97 14.44]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def f(x):
    return 8*(x**5) - 10*(x**4) + x**3 + 2*(x**2) + 9*x + 13
def g(x):
    return 40*(x**4) - 40*(x**3) + 3*(x**2) + 4*x + 9

def newton_raphson(x, tol=0.031, max_iter=50):
    found = False
    for i in range(max_iter):
        x = x - (f(x)/g(x))

        print(f"Iteration #{i+1}: {x}")
        if np.abs(f(x)) < tol:
            print(f"Root found at {i+1} iteration: {x}")
            return
        
newton_raphson(5)
# Out:
# Iteration #1: 4.055760047751691
# Iteration #2: 3.2995992993701333
# Iteration #3: 2.691142040353687
# Iteration #4: 2.1941206124780868
# Iteration #5: 1.7693673505975802
# Iteration #6: 1.3536896666513434
# Iteration #7: 0.7335064821901164
# Iteration #8: -1.3942760169601534
# Iteration #9: -1.1029655134470373
# Iteration #10: -0.9073243206569388
# Iteration #11: -0.815342818303601
# Iteration #12: -0.7972383775051456
# Root found at 12 iteration: -0.7972383775051456

# %%
def f(x):
    return 40*(x**4) - 40*(x**3) + 3*(x**2) + 4*x - 9

a = 5
b = 15
points = 60000
width = (b-a) / (points-1)
x = np.linspace(a, b, points)

rightRiemann = width * np.sum(f(x[1:]))
mid = (x[:-1] + x[1:]) / 2
midRiemann = width * np.sum(f(mid))
print(f"Right: {rightRiemann}")
print(f"Mid: {midRiemann}")
# Out:
# Right: 5553715.890413146
# Mid: 5553559.999425837
